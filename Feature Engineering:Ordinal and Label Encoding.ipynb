# %% [markdown]
# <a href="https://www.kaggle.com/code/victoraesthete/feature-engineering-ordinal-and-label-encoding?scriptVersionId=118060169" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Encoding: Ordinal and Label

# %%
#Import Reqired liberaries
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/kaggle/input/udacity-course-catalog/all_courses.csv",usecols=['Title','Level','Type','Rating'],nrows=100)
df.sample(10)
# Out:
#                                                 Title        Type  \
# 90                       Data Visualization and D3.js        free
# 55              Cloud Native Application Architecture  nanodegree
# 29                         Robotics Software Engineer  nanodegree
# 51                                      iOS Developer  nanodegree
# 35  Data Analysis and Visualization with Microsoft...  nanodegree
# 5                         Introduction to Programming  nanodegree
# 33                              Cloud DevOps Engineer  nanodegree
# 23                             Growth Product Manager  nanodegree
# 12                                                SQL  nanodegree
# 22                                Intermediate Python  nanodegree
#
#            Level  Rating
# 90  intermediate     NaN
# 55  intermediate     4.7
# 29      advanced     4.5
# 51      beginner     4.6
# 35      beginner     4.7
# 5       beginner     4.7
# 33  intermediate     4.6
# 23  intermediate     4.5
# ...

# %%
df.iloc[:,1:]
# Out:
#           Type         Level  Rating
# 0   nanodegree  intermediate     4.6
# 1   nanodegree      beginner     4.7
# 2   nanodegree  intermediate     4.5
# 3   nanodegree      beginner     4.8
# 4   nanodegree      advanced     4.7
# ..         ...           ...     ...
# 95        free  intermediate     NaN
# 96        free  intermediate     NaN
# 97        free      advanced     NaN
# 98        free  intermediate     NaN
# 99        free  intermediate     NaN
#
# [100 rows x 3 columns]

# %% [markdown]
# # 1. Train-Test-Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(df.iloc[:,[2]], df.iloc[:,[1]],test_size=0.3)

# %%
X_train
# Out:
#            Level
# 40      advanced
# 7   intermediate
# 23  intermediate
# 1       beginner
# 44      beginner
# ..           ...
# 57      beginner
# 78      beginner
# 10  intermediate
# 61  intermediate
# 47  intermediate
#
# [70 rows x 1 columns]

# %% [markdown]
# # 2. Ordinal Encoding

# %%
# For Ordinal Categorical Data - having order

# %%
from sklearn.preprocessing import OrdinalEncoder  #Step 1: Import

# %%
oe=OrdinalEncoder(categories=[['beginner','intermediate','advanced']])   #Step 2: Create object

# %%
oe.fit(X_train)  #Step 3: Fit train data in object
# Out:
# OrdinalEncoder(categories=[['beginner', 'intermediate', 'advanced']])

# %%
X_train=oe.transform(X_train)    #step 4: Transform Train
X_test=oe.transform(X_test)      #And Test data

# %%
X_train
# Out:
# array([[2.],
#        [1.],
#        [1.],
#        [0.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [0.],
#        [0.],
#        [0.],
#        [1.],
#        [1.],
#        [2.],
#        [1.],
#        [1.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [1.],
#        [2.],
#        [2.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [2.],
#        [2.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [0.],
# ...

# %% [markdown]
# # 3. Label Encoding

# %%
# For Label/Output Column

# %%
from sklearn.preprocessing import LabelEncoder  #Step 1: Import

# %%
le=LabelEncoder()    #Step 2: Create object

# %%
le.fit(y_train)    #Step 3: Fit train data in object
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LabelEncoder()

# %%
#check classes
le.classes_
# Out:
# array(['course', 'free', 'nanodegree'], dtype=object)

# %%
#Step 4: Transformion
y_train=le.transform(y_train)   # train data
y_test=le.transform(y_test)    # test data
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_train
# Out:
# array([2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 2, 1, 0, 2, 2, 1, 2, 2, 2, 0, 2, 2,
#        1, 2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2,
#        2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2])
